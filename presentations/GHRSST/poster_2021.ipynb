# %% [markdown]
# # Poster(s) 2021

# %%
# %matplotlib inline

from importlib import reload
import os
import numpy as np

import pandas

import h5py
import seaborn as sns
import pandas as pd
import umap
from ulmo import io as ulmo_io
from ulmo import plotting
from ulmo.ssl import single_image as ssl_simage

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from matplotlib import pyplot as plt

# %% [markdown]
# # Grab an image for augmenting

# %%
modis_dataset_path = "/home/xavier/Projects/Oceanography/AI/OOD/MODIS_L2/PreProc/MODIS_R2019_2003_95clear_128x128_preproc_std.h5"
with ulmo_io.open(modis_dataset_path, 'rb') as f:
    hf = h5py.File(f, 'r')
    img = hf['valid'][400]
img.shape
# Out:
# (1, 64, 64)

# %%
plotting.show_image(img[0,...])
# Out:
# <AxesSubplot:>

# %%
image_transposed = np.transpose(img, (1, 2, 0))

# %%
image_transposed.shape
# Out:
# (64, 64, 1)

# %% [markdown]
# # Test loader

# %%
loader = ssl_simage.image_loader(img)

# %%
test_batch = iter(loader).next()
# Out:
# random angle = [330.9869]
# random angle = [103.53466]

# %%
img1, img2 = test_batch

# %%
plotting.show_image(img1[0,0,...])
# Out:
# <AxesSubplot:>

# %%
plotting.show_image(img2[0,0,...])
# Out:
# <AxesSubplot:>

# %%
plotting.show_image(img[0,...])
# Out:
# <AxesSubplot:>

# %%
loader2 = ssl_simage.image_loader(img)

# %%
np.random.seed(1234)

# %%
test_batch2 = iter(loader2).next()
# Out:
# random angle = [68.947]
# random angle = [140.97731]
