# %% [markdown]
# # Train R2019 2010 on Gradients

# %% [markdown]
# # imports

# %%
from ulmo.models import DCAE, ConditionalFlow
from ulmo.ood import ood
# Out:
# Cartopy not installed.  Some plots will not work!

# %% [markdown]
# # Init Model

# %%
datadir='./R2019_2010_128x128_grad'
pae = ood.ProbabilisticAutoencoder.from_json('./pae_model_std.json', 
                                             filepath='./PreProc/MODIS_R2019_2010_95clear_128x128_preproc_grad.h5',
                                             datadir=datadir, logdir=datadir)

# %% [markdown]
# # Train the AutoEncoder

# %%
pae.train_autoencoder(n_epochs=10, batch_size=256, lr=2.5e-3, summary_interval=50, eval_interval=1000)
# Out:
# 135,680 training samples. 542,720 validation samples.
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=530.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=530.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=530.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=530.0), HTML(value='')))
# Training stopped. Save model (y/n)? y
# Model saved.
# Loading autoencoder model from: ./R2019_2010_128x128_grad/autoencoder.pt

# %% [markdown]
# ## Examine outputs

# %%
pae.plot_reconstructions()

# %% [markdown]
# # Flow

# %%
pae.train_flow(n_epochs=10, batch_size=64, lr=2.5e-4, summary_interval=50, eval_interval=1000)
# Out:
# 137,216 training samples. 544,768 validation samples.
# HBox(children=(FloatProgress(value=0.0, description='Computing train latents', max=67.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='Computing valid latents', max=266.0, style=ProgressStyle(…
# 135,680 training samples. 542,784 validation samples.
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2120.0), HTML(value='')))
# Training stopped. Save model (y/n)? y
# Model saved.
# Loading flow model from: ./R2019_2010_128x128_grad/flow.pt

# %% [markdown]
# # Probabilities

# %%
pae.plot_log_probs()
# Out:
# 136,192 training samples. 543,744 validation samples.
# HBox(children=(FloatProgress(value=0.0, description='Computing train log probs', max=133.0, style=ProgressStyl…
# HBox(children=(FloatProgress(value=0.0, description='Computing valid log probs', max=531.0, style=ProgressStyl…

# %% [markdown]
# # Plot

# %%
pae.plot_grid('least likely', vmin=0, vmax=5, grad_vmax=3, save_figure=True)

# %% [markdown]
# # Save

# %%
pae.save_log_probs()
# Out:
# Saved log probabilities to ./R2019_2010_128x128_grad/MODIS_R2019_2010_95clear_128x128_preproc_grad_log_probs.csv.
