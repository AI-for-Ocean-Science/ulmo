# %% [markdown]
# # Checking Kinematic Cutouts

# %%
# imports
import h5py

from ulmo.plotting import plotting

# %% [markdown]
# # Grab one

# %%
sst_file = 'PreProc/LLC_FS_test_preproc.h5'
divb_file = 'PreProc/LLC_FS_test_preproc_divb.h5'

# %%
idx = 590

# %% [markdown]
# ## SST

# %%
sst_f = h5py.File(sst_file, 'r')
sst = sst_f['valid']
sst.shape
# Out:
# (1971, 1, 64, 64)

# %%
plotting.show_image(sst[idx,0,...], set_aspect='equal')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## $|\nabla b|^2$

# %%
divb_f = h5py.File(divb_file, 'r')
divb = divb_f['valid']
divb.shape
# Out:
# (1971, 1, 64, 64)

# %%
plotting.show_image(divb[idx,0,...], set_aspect='equal')
# Out:
# <AxesSubplot:>
