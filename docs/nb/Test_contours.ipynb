# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt

matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
rv1 = multivariate_normal([0., 0.], [[1., 0.], [0., 1.]])
Z1 = rv1.pdf(np.dstack((X, Y)))
rv2 = multivariate_normal([1, 1], [[1.5, 0.], [0., 0.5]])
Z2 = rv2.pdf(np.dstack((X, Y)))
# difference of Gaussians
Z = 10.0 * (Z2 - Z1)

# Create a simple contour plot with labels using default colors.  The
# inline argument to clabel will control whether the labels are draw
# over the line segments of the contour, removing the lines beneath
# the label
plt.figure()
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
plt.title('Simplest default with labels')
# Out:
# Text(0.5, 1.0, 'Simplest default with labels')

# %%
dat0= CS.allsegs[1][0]
dat1= CS.allsegs[2][0]
dat2= CS.allsegs[3][0]
dat3= CS.allsegs[4][0]

plt.plot(dat0[:,0],dat0[:,1])
plt.plot(dat1[:,0],dat1[:,1])
plt.plot(dat2[:,0],dat2[:,1])
plt.plot(dat3[:,0],dat3[:,1])

# %%
type(CS)
# Out:
# matplotlib.contour.QuadContourSet

# %%
path = CS.collections[1].get_paths()
seg1 = path[0].vertices
seg2 = CS.allsegs[0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-fb16e29b8a5c> in <module>
#       1 path = CS.collections[1].get_paths()
#       2 seg1 = path[0].vertices
# ----> 3 seg2 = CS.allsegs[0][0]
#
# IndexError: list index out of range

# %%
seg2 == seg1
# Out:
# <ipython-input-43-64b5dd3cdea5>:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   CS.allsegs[1][0] == seg1
# False

# %%
seg1.shape
# Out:
# (75, 2)

# %%
seg2.shape
# Out:
# (105, 2)

# %%
len(CS.allsegs)
# Out:
# 9

# %%
path6 = CS.collections[6].get_paths()
data6 = path6[0].vertices
plt.plot(data6[:,0], data6[:,1])

path7 = CS.collections[7].get_paths()
data7 = path7[0].vertices
plt.plot(data7[:,0], data7[:,1])

# %%
CS.collections[6].get_paths()
# Out:
# [Path(array([[1.67994656, 0.4408169 ],
#         [1.7       , 0.43996989],
#         [1.725     , 0.43939523],
#         [1.75      , 0.43931353],
#         [1.775     , 0.4397369 ],
#         [1.8       , 0.44067786],
#         [1.825     , 0.44214942],
#         [1.85      , 0.44416505],
#         [1.875     , 0.44673877],
#         [1.9       , 0.44988517],
#         [1.90078216, 0.45      ],
#         [1.925     , 0.45366608],
#         [1.95      , 0.45806118],
#         [1.975     , 0.46308599],
#         [2.        , 0.46875823],
#         [2.02462698, 0.475     ],
#         [2.025     , 0.47509801],
#         [2.05      , 0.48223975],
#         [2.075     , 0.49010108],
#         [2.1       , 0.49870378],
#         [2.10352264, 0.5       ],
#         [2.125     , 0.50823763],
#         [2.15      , 0.51860538],
#         [2.16440613, 0.525     ],
#         [2.175     , 0.52992461],
#         [2.2       , 0.54228522],
#         [2.21466661, 0.55      ],
# ...

# %%
dat = CS.allsegs[7][0]
plt.plot(dat[:,0], dat[:,1])

# %%
dat.shape
# Out:
# (149, 2)

# %%
data.shape
# Out:
# (125, 2)

# %%
from skimage import measure


# Construct some test data
x, y = np.ogrid[-np.pi:np.pi:100j, -np.pi:np.pi:100j]
r = np.sin(np.exp((np.sin(x)**3 + np.cos(y)**2)))

# Find contours at a constant value of 0.8
contours = measure.find_contours(r, 0.8)

# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(r, cmap=plt.cm.gray)

for contour in contours:
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
contours
# Out:
# [array([[9.93902734, 0.        ],
#         [9.86521017, 1.        ],
#         [9.63842842, 2.        ],
#         [9.24067178, 3.        ],
#         [9.        , 3.42487608],
#         [8.64744355, 4.        ],
#         [8.        , 4.80005934],
#         [7.80754532, 5.        ],
#         [7.        , 5.71101032],
#         [6.56942992, 6.        ],
#         [6.        , 6.3556701 ],
#         [5.        , 6.79944214],
#         [4.31568262, 7.        ],
#         [4.        , 7.09578373],
#         [3.        , 7.28305412],
#         [2.        , 7.37835474],
#         [1.        , 7.41346629],
#         [0.        , 7.41849616]]),
#  array([[ 0.        , 42.09146193],
#         [ 1.        , 42.09626078],
#         [ 2.        , 42.12974181],
#         [ 3.        , 42.2204602 ],
#         [ 4.        , 42.39806193],
#         [ 5.        , 42.69644371],
#         [ 5.67419922, 43.        ],
#         [ 6.        , 43.14925559],
#         [ 7.        , 43.78701929],
# ...
