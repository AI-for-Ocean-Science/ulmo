# %% [markdown]
# # LLC Extraction

# %%
# %matplotlib notebook

# %%
# imports
import os
import numpy as np

import pandas

import h5py

from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.ticker as mticker

import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import seaborn as sns

from ulmo.utils import image_utils
import unyt

# Astronomy tools
import astropy_healpix
from astropy import units
from astropy.coordinates import SkyCoord, match_coordinates_sky

# %% [markdown]
# # First one was run to grab the mapping
#
# ## ulmo_extract_llc --debug

# %% [markdown]
# # Explore that

# %% [markdown]
# ## Load

# %%
ex_file = os.path.join(os.getenv('SST_OOD'), 'LLC', 'Extractions', 
                       'debug_one_for_coords.h5')

# %%
f = h5py.File(ex_file, mode='r')

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['fields', 'masks', 'metadata']>

# %% [markdown]
# ## Metadata

# %%
meta = f['metadata']
df = pandas.DataFrame(meta[:].astype(np.unicode_), columns=meta.attrs['columns'])

# %%
df.latitude = df.latitude.values.astype(float)
df.longitude = df.longitude.values.astype(float)

# %%
df.head()
# Out:
#                          filename   row column    latitude   longitude  \
# 0  LLC4320_2012-02-03T00_00_00.nc  1752  11040   -78.20546  -163.75221
# 1  LLC4320_2012-02-03T00_00_00.nc  1756  11024   -78.19663  -164.12633
# 2  LLC4320_2012-02-03T00_00_00.nc  1757  11056  -78.154976  -163.45134
# 3  LLC4320_2012-02-03T00_00_00.nc  1759  11018   -78.18334  -164.27869
# 4  LLC4320_2012-02-03T00_00_00.nc  1768  11008    -78.1345  -164.56404
#
#    clear_fraction
# 0    0.0478515625
# 1   0.04541015625
# 2   0.04541015625
# 3    0.0498046875
# 4  0.041259765625

# %% [markdown]
# ## Write to disk

# %%
df.to_csv('all_extract_coords_LLC.csv')

# %% [markdown]
# ## Spatial plot

# %%
# Healpix me
nside = 32
hp_events, hp_lons, hp_lats = image_utils.evals_to_healpix(
    df, nside, log=False, mask=True)

# %%
fig = plt.figure(figsize=(11, 7))
plt.clf()

tformM = ccrs.Mollweide()
tformP = ccrs.PlateCarree()

ax = plt.axes(projection=tformM)


cm = plt.get_cmap('Blues')
# Cut
good = np.invert(hp_events.mask)
img = plt.scatter(x=hp_lons[good],
    y=hp_lats[good],
    c=hp_events[good],
    cmap=cm,
    s=1,
    transform=tformP)
#
# Colorbar
cb = plt.colorbar(img, orientation='horizontal', pad=0.)
#clbl=r'$\log_{10} \, N_{\rm '+'{}'.format(lbl)+'}$'
#cb.set_label(clbl, fontsize=20.)
cb.ax.tick_params(labelsize=17)

# Coast lines
ax.coastlines(zorder=10)
ax.set_global()

#
#plt.savefig('aph_spatial_1st.png', dpi=300)

plt.show()

# %% [markdown]
# ## Output for PC

# %%
df.to_csv('LLC_first_extractions.csv')

# %%
df
# Out:
#                               filename    row column   latitude  longitude  \
# 0       LLC4320_2012-02-03T00_00_00.nc   1752  11040 -78.205460 -163.75221
# 1       LLC4320_2012-02-03T00_00_00.nc   1756  11024 -78.196630 -164.12633
# 2       LLC4320_2012-02-03T00_00_00.nc   1757  11056 -78.154976 -163.45134
# 3       LLC4320_2012-02-03T00_00_00.nc   1759  11018 -78.183340 -164.27869
# 4       LLC4320_2012-02-03T00_00_00.nc   1768  11008 -78.134500 -164.56404
# ...                                ...    ...    ...        ...        ...
# 473976  LLC4320_2012-02-03T00_00_00.nc  12895  10588  71.716606 -177.66539
# 473977  LLC4320_2012-02-03T00_00_00.nc  12895  11619  70.833010 -151.49582
# 473978  LLC4320_2012-02-03T00_00_00.nc  12895  11648  70.771120 -150.80946
# 473979  LLC4320_2012-02-03T00_00_00.nc  12895  13632  69.241840 -117.67405
# 473980  LLC4320_2012-02-03T00_00_00.nc  12895  14297  70.957330 -103.04633
#
#         clear_fraction
# 0         0.0478515625
# 1        0.04541015625
# 2        0.04541015625
# 3         0.0498046875
# 4       0.041259765625
# ...                ...
# 473976  0.049560546875
# 473977     0.048828125
# 473978  0.042724609375
# 473979        0.046875
# 473980   0.04833984375
#
# [473981 rows x 6 columns]

# %%
360*180.
# Out:
# 64800.0

# %% [markdown]
# ----

# %% [markdown]
# # Healpix

# %%
circ = 2 * np.pi * unyt.R_Earth
circ.to('km')
# Out:
# unyt_quantity(40030.22398037, 'km')

# %%
ang_50km = (360./circ) * 50*unyt.km * unyt.deg
ang_50km.to('deg')
# Out:
# unyt_quantity(0.44966024, 'degree')

# %% [markdown]
# ## Healpix the globe

# %%
nside = astropy_healpix.pixel_resolution_to_nside(0.5*units.deg)
nside
# Out:
# 128

# %%
hp = astropy_healpix.HEALPix(nside=nside)
hp.pixel_resolution
# Out:
# <Quantity 27.48389129 arcmin>

# %%
hp_lon, hp_lat = hp.healpix_to_lonlat(np.arange(hp.npix))

# %%
hp_lon.size
# Out:
# 196608

# %% [markdown]
# ### Plot

# %%
fig = plt.figure(figsize=(7, 4))
plt.clf()

tformM = ccrs.Mollweide()
tformP = ccrs.PlateCarree()

ax = plt.axes(projection=tformM)


cm = plt.get_cmap('Blues')
# Cut
#good = np.invert(hp_events.mask)
img = plt.scatter(x=hp_lon.to('deg').value,
    y=hp_lat.to('deg').value,
    #c=hp_events[good],
    #cmap=cm,
    s=0.01,
    transform=tformP)
#
# Colorbar
cb = plt.colorbar(img, orientation='horizontal', pad=0.)
#clbl=r'$\log_{10} \, N_{\rm '+'{}'.format(lbl)+'}$'
#cb.set_label(clbl, fontsize=20.)
cb.ax.tick_params(labelsize=17)

# Coast lines
ax.coastlines(zorder=10)
ax.set_global()

#
#plt.savefig('aph_spatial_1st.png', dpi=300)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.6">

# %% [markdown]
# ## Coords

# %%
hp_coord = SkyCoord(hp_lon, hp_lat, frame='galactic')

# %%
llc_coord = SkyCoord(df.longitude.values*units.deg + 180.*units.deg, df.latitude.values*units.deg, frame='galactic')

# %% [markdown]
# ## Cross-match

# %%
idx, sep2d, _ = match_coordinates_sky(hp_coord, llc_coord, nthneighbor=1)

# %%
good = sep2d < hp.pixel_resolution
np.sum(good)
# Out:
# 133325

# %%
flag = np.zeros(len(llc_coord), dtype='bool')
for ii in np.where(good)[0]:
    flag[idx[ii]] = True
np.sum(flag)
# Out:
# 132746

# %%
df[flag]
# Out:
#                               filename    row column   latitude  longitude  \
# 0       LLC4320_2012-02-03T00_00_00.nc   1752  11040 -78.205460 -163.75221
# 3       LLC4320_2012-02-03T00_00_00.nc   1759  11018 -78.183340 -164.27869
# 11      LLC4320_2012-02-03T00_00_00.nc   1768  11120 -78.012050 -162.17952
# 25      LLC4320_2012-02-03T00_00_00.nc   1784  11120 -77.907260 -162.30516
# 32      LLC4320_2012-02-03T00_00_00.nc   1784  11232 -77.782390 -159.94469
# ...                                ...    ...    ...        ...        ...
# 473976  LLC4320_2012-02-03T00_00_00.nc  12895  10588  71.716606 -177.66539
# 473977  LLC4320_2012-02-03T00_00_00.nc  12895  11619  70.833010 -151.49582
# 473978  LLC4320_2012-02-03T00_00_00.nc  12895  11648  70.771120 -150.80946
# 473979  LLC4320_2012-02-03T00_00_00.nc  12895  13632  69.241840 -117.67405
# 473980  LLC4320_2012-02-03T00_00_00.nc  12895  14297  70.957330 -103.04633
#
#         clear_fraction
# 0         0.0478515625
# 3         0.0498046875
# 11      0.013427734375
# 25                 0.0
# 32       0.03857421875
# ...                ...
# 473976  0.049560546875
# 473977     0.048828125
# 473978  0.042724609375
# 473979        0.046875
# 473980   0.04833984375
#
# [132746 rows x 6 columns]

# %% [markdown]
# ### Plot

# %%
fig = plt.figure(figsize=(7, 4))
plt.clf()

tformM = ccrs.Mollweide()
tformP = ccrs.PlateCarree()

ax = plt.axes(projection=tformM)


cm = plt.get_cmap('Blues')
# Cut
#good = np.invert(hp_events.mask)
img = plt.scatter(x=df.longitude[flag],
    y=df.latitude[flag],
    #c=hp_events[good],
    #cmap=cm,
    s=0.01,
    transform=tformP)
#
# Colorbar
cb = plt.colorbar(img, orientation='horizontal', pad=0.)
#clbl=r'$\log_{10} \, N_{\rm '+'{}'.format(lbl)+'}$'
#cb.set_label(clbl, fontsize=20.)
cb.ax.tick_params(labelsize=17)

# Coast lines
ax.coastlines(zorder=10)
ax.set_global()

#
#plt.savefig('aph_spatial_1st.png', dpi=300)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="699.6">
