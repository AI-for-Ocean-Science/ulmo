# %%
# imports
from importlib import reload

import os # a module to interact with the operating system
os.environ["ENDPOINT_URL"]="http://rook-ceph-rgw-nautiluss3.rook"
import numpy as np

import pandas as pd
import xarray
import h5py

from matplotlib import pyplot as plt
import seaborn as sns
import scipy.stats as stats

from ulmo import io as ulmo_io
from ulmo import plotting
from ulmo.llc import io as llc_io
from ulmo.llc import plotting as llc_plotting

from ulmo.utils import image_utils
from ulmo.analysis import figures as ulmo_figs
from ulmo.plotting import plotting as ulmo_plotting

# %%
new_tbl_file = 's3://modis-l2/Tables/MODIS_L2_std.parquet'
mod_table = ulmo_io.load_main_table(new_tbl_file)
# Out:
# Read main table: s3://modis-l2/Tables/MODIS_L2_std.parquet

# %%
mod_table['DT'] = mod_table.T90 - mod_table.T10
mod_table['DT_abs'] = mod_table.Tmax - mod_table.Tmin

# %%
year_2012 = mod_table[(mod_table.datetime >= pd.to_datetime('2012-01-01 00:00:00')) & (mod_table.datetime < pd.to_datetime('2012-11-15 11:35:00'))]

# %%
year_2012.head()
# Out:
#                lat       lon  col            datetime          LL  row  \
# 5854570  36.135740 -3.848738  453 2012-01-01 02:05:00  318.187195  816
# 5864483  35.531757 -7.622594  197 2012-01-01 02:05:00  125.284912  930
# 5869390  35.672420 -2.118561  613 2012-01-01 02:05:00  348.785034  840
# 5881776  35.769630 -3.190676  517 2012-01-01 02:05:00  313.916565  846
# 5889532  36.795265 -1.164854  667 2012-01-01 02:05:00  130.362183  703
#
#          clear_fraction  mean_temperature       Tmin       Tmax  ...  \
# 5854570        0.024536         15.801380  14.620000  16.594999  ...
# 5864483        0.049194         17.166348  14.980000  18.029999  ...
# 5869390        0.049011         16.115070  15.134999  16.645000  ...
# 5881776        0.047546         15.890429  14.580000  16.625000  ...
# 5889532        0.048706         15.823463  14.855000  16.984999  ...
#
#                T10                              filename                  UID  \
# 5854570  15.304999  AQUA_MODIS.20120101T020508.L2.SST.nc  1325126135717615126
# 5864483  16.764999  AQUA_MODIS.20120101T020508.L2.SST.nc  1325125531817237741
# 5869390  15.844999  AQUA_MODIS.20120101T020508.L2.SST.nc  1325125672417788144
# 5881776  15.594999  AQUA_MODIS.20120101T020508.L2.SST.nc  1325125769617680932
# 5889532  15.380000  AQUA_MODIS.20120101T020508.L2.SST.nc  1325126795317883515
#
#                                                    pp_file   pp_root  \
# 5854570  s3://modis-l2/PreProc/MODIS_R2019_2011_95clear...  standard
# 5864483  s3://modis-l2/PreProc/MODIS_R2019_2011_95clear...  standard
# 5869390  s3://modis-l2/PreProc/MODIS_R2019_2011_95clear...  standard
# 5881776  s3://modis-l2/PreProc/MODIS_R2019_2011_95clear...  standard
# 5889532  s3://modis-l2/PreProc/MODIS_R2019_2011_95clear...  standard
#
#         field_size  pp_type  pp_idx        DT    DT_abs
# 5854570        128        0   41054  0.900001  1.974999
# 5864483        128        0   50967  0.795000  3.049999
# 5869390        128        0   55874  0.505001  1.510001
# 5881776        128        0   68260  0.610001  2.045000
# 5889532        128        0   76016  0.944999  2.129999
#
# [5 rows x 21 columns]

# %% [markdown]
# # sharp temperature gradient

# %%
temp_grad = year_2012[ (year_2012.DT >8) & (year_2012.LL < -1000) ]
temp_grad.shape
# Out:
# (89, 21)

# %%
list = np.random.choice( np.arange(0, temp_grad.shape[0], 1), 5)

# %%
fig, axes = plt.subplots(5, 1, figsize = (5, 25) )

_, cm = ulmo_plotting.load_palette()

    
for i, elem in enumerate(list):
    
    with ulmo_io.open( 's3://modis-l2/PreProc/MODIS_R2019_2012_95clear_128x128_preproc_std.h5' , 'rb') as f:
        pp_hf = h5py.File(f, 'r')
    
        img = pp_hf['valid'][elem, 0, ...]
        mean_T = pp_hf['valid_metadata'][elem,7]
    
        pp_hf.close()

    ax = axes[i]
    g = sns.heatmap(np.flipud(img), xticklabels = [], yticklabels = [], cmap=cm, ax = ax)
    tmp = float( mean_T.decode() )
    g.set_title('Mean T: {} C '.format(round(tmp)))

plt.show()
