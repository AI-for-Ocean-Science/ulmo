# %%
# imports
from importlib import reload

import os # a module to interact with the operating system
os.environ["ENDPOINT_URL"]="http://rook-ceph-rgw-nautiluss3.rook"
import numpy as np

import pandas as pd
import xarray
import h5py
import healpy as hp
import time
import scipy.io

import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

from matplotlib import pyplot as plt
import seaborn as sns
import scipy.stats as stats

from ulmo import io as ulmo_io
from ulmo import plotting
from ulmo.llc import io as llc_io
from ulmo.llc import plotting as llc_plotting

from ulmo.utils import image_utils
from ulmo.analysis import figures as ulmo_figs
from ulmo.plotting import plotting as ulmo_plotting
from ulmo.analysis import spatial_plots as sp
from py import figs_llc_viirs

# %% [markdown]
# ## Figures found in figs_llc_viirs.py

# %%
figs_llc_viirs.fig_LL_histograms(local=False)
# Out:
# Read main table: s3://llc/Tables/llc_viirs_match.parquet
# Read main table: s3://viirs/Tables/VIIRS_all_98clear_std.parquet
# N VIIRS: 1140923
# N LLC: 1024340
# Medians:  VIIRS=206.18609619140625, LLC=281.330078125
# Quantiles: q=0.25, viirs=22.03857421875, llc=58.727508544921875
# Quantiles: q=0.5, viirs=206.18609619140625, llc=281.330078125
# Quantiles: q=0.75, viirs=376.10052490234375, llc=477.6049041748047
# VIIRS: 1135978
# LLC: 1012516
# Wrote fig_LL_histograms.png

# %%
figs_llc_viirs.fig_explore_highLL(local=False)
# Out:
# Read main table: s3://llc/Tables/llc_viirs_match.parquet
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:475: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# Wrote fig_explore_highLL.png

# %%
figs_llc_viirs.fig_med_LL_head_tail()
# Out:
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:475: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
figs_llc_viirs.fig_med_LL_VIIRS_LLC()
# Out:
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:475: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# Wrote: med_LL_diff_VIIRS_vs_LLC.png

# %%
figs_llc_viirs.fig_viirs_concentration()
# Out:
# /home/jovyan/ulmo/papers/LLC/SST_Compare/Figures/py/figs_llc_viirs.py:308: RuntimeWarning: divide by zero encountered in log10
#   c=np.log10(evts_v98)[good],
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:475: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# Wrote: viirs_concentration.png

# %%
figs_llc_viirs.fig_viirs_llc_variability()
# Out:
# Wrote: Variability_med_LL_diff_VIIRS_vs_LLC.png

# %%
figs_llc_viirs.fig_med_LL_diff_head_vs_tail()
# Out:
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:475: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '
# /opt/conda/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '
# Wrote: med_LL_diff_head_vs_tail.png

# %%
figs_llc_viirs.fig_gulfstream()
# Out:
# Wrote: fig_gulfstream.png

# %%
figs_llc_viirs.fig_eq_pacific()
# Out:
# Read main table: s3://viirs/Tables/VIIRS_all_98clear_std.parquet
# Read main table: s3://llc/Tables/LLC_uniform144_r0.5.parquet
# Wrote fig_equator_histograms.png

# %%
figs_llc_viirs.fig_decile_gallery(cut='full_5')
# Out:
# Read main table: s3://llc/Tables/llc_viirs_match.parquet
# Read main table: s3://viirs/Tables/VIIRS_all_98clear_std.parquet
# Temperature scale is nan to nan.
# /home/jovyan/ulmo/papers/LLC/SST_Compare/Figures/py/figs_llc_viirs.py:776: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0, .9, 1])
# Wrote fig_gallery_full_5.png
